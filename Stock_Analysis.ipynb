# %%
import pandas as pd
import numpy as np
pd.core.common.is_list_like = pd.api.types.is_list_like
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
import matplotlib.pyplot as plt

yf.pdr_override()

# %%
sp500=pdr.get_data_yahoo('^GSPC','1980-01-01','2018-07-30')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
close_price = sp500['Adj Close']
close_price.plot()
plt.xlabel('Date')
plt.ylabel('Adjusted Closing Price')
plt.title('S&P 500 Historical Data')
plt.legend()
plt.show()

# %%
close_dt=np.nan_to_num(sp500['Adj Close'].pct_change())
close_ln= np.log(sp500['Adj Close']) - np.log(sp500['Adj Close'].shift(1))
print((np.mean(close_ln)+1)**250)
# Out:
# 1.0878517029839498

# %%
xvals = np.arange(0.5,1.5,0.01)


fig=plt.figure()
ax1=fig.add_subplot(1,1,1)

ax1.plot(xvals, np.log(xvals), '-')
ax1.plot(xvals, xvals-1,'-')

plt.show()

# %%
adj_close[-1]/adj_close[0] -1
# Out:
# 25.4996222106728

# %%
np.log(adj_close/adj_lclose)
